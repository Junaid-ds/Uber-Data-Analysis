# %% [markdown]
# <a href="https://colab.research.google.com/github/Junaid-ds/Uber-Data-Analysis/blob/main/Uber_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('UberDataset.csv')
data
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data.shape
# Out:
# (1156, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# # **Data Preprocessing**

# %%
data['PURPOSE'].fillna('NOT', inplace=True)

# %%
data.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NOT
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
data['START_DATE'] = pd.to_datetime(data['START_DATE'], errors= 'coerce')
data['END_DATE'] = pd.to_datetime(data['END_DATE'], errors = 'coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
data['Date'] = pd.DatetimeIndex(data['START_DATE']).date
data['Time'] = pd.DatetimeIndex(data['START_DATE']).time

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        Date      Time
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21:11:00
# 1      Fort Pierce    5.0              NOT  2016-01-02  01:25:00
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20:25:00
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17:31:00
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14:42:00

# %%
data['Day-Night'] = pd.cut(x=data['Time'].apply(lambda x: x.hour),
                         bins = [0,10,15,19,24],
                         labels=['Morning','Afternoon','Evening','Night'],
                         include_lowest=True,
                         right=False)

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        Date      Time   Day-Nigh  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21:11:00      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02  01:25:00    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20:25:00      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17:31:00    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14:42:00  Afternoon
#
#    Day-Night
# 0      Night
# 1    Morning
# 2      Night
# 3    Evening
# 4  Afternoon

# %%
data.dropna(inplace = True)

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (20,5))
plt.subplot(1,2,1)
sns.countplot(data['CATEGORY'])

plt.subplot(1,2,2)
sns.countplot(data['PURPOSE'])
# Out:
# <Axes: xlabel='count', ylabel='PURPOSE'>

# %%
plt.figure(figsize = (10,5))
sns.countplot(data['Day-Night'])
plt.show()

# %%
data['Month'] = pd.DatetimeIndex(data['START_DATE']).month
month_label = {1.0:'Jan',2.0:'Feb',3.0:'Mar',4.0:'Apr',5.0:'May',6.0:'Jun',7.0:'Jul',8.0:'Aug',9.0:'Sep',10.0:'Oct',11.0:'Nov',12.0:'Dec'}

data['Month'] = data.Month.map(month_label)

mon = data.Month.value_counts(sort = False)
# Out:
# Month
# Jan    23
# Feb    40
# Mar    42
# Apr    25
# May    26
# Jun    42
# Jul    40
# Aug    43
# Sep    13
# Oct    24
# Nov    63
# Dec    39
# Name: count, dtype: int64

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        Date      Time   Day-Nigh  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21:11:00      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02  01:25:00    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20:25:00      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17:31:00    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14:42:00  Afternoon
#
#    Day-Night Month
# 0      Night   Jan
# 1    Morning   Jan
# 2      Night   Jan
# 3    Evening   Jan
# ...

# %%
df = pd.DataFrame({"Month" : mon.values,
                   "Value_Count" : data.groupby('Month', sort = False)['MILES'].max()
})

p = sns.lineplot(data = df)
p.set(xlabel = 'Month', ylabel = 'Value_Count')
#
# Out:
# [Text(0.5, 0, 'Month'), Text(0, 0.5, 'Value_Count')]

# %%
data['Day'] = data.START_DATE.dt.weekday

day_label = {0:"Monday",1:"Tuesday",2:"Wednesday",3:"Thursday",4:"Friday",5:"Saturday",6:"Sunday"}

data['Day'] = data.Day.map(day_label)

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        Date      Time   Day-Nigh  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21:11:00      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02  01:25:00    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20:25:00      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17:31:00    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14:42:00  Afternoon
#
#    Day-Night Month        Day
# 0      Night   Jan     Friday
# 1    Morning   Jan   Saturday
# ...

# %%
dl = data.Day.value_counts()

plt.figure(figsize = (10,5))
sns.barplot(x = dl.index, y = dl)
plt.xlabel('DAY')
plt.ylabel('Value_Count')
plt.show()

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        Date      Time   Day-Nigh  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21:11:00      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02  01:25:00    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20:25:00      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17:31:00    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14:42:00  Afternoon
#
#    Day-Night Month        Day
# 0      Night   Jan     Friday
# 1    Morning   Jan   Saturday
# ...

# %%
plt.figure(figsize = (10,5))
sns.boxplot(data['MILES'])
plt.show()

# %%
sns.boxplot(data[data['MILES']<100].MILES)
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.boxplot(data[data["MILES"] < 40]["MILES"])
# Out:
# <Axes: ylabel='MILES'>
